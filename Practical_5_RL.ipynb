# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51236/Reinforcement-Learning-Practical/blob/main/Practical_5_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name):
    env = gym.make(env_name)
    state, info = env.reset()

    total_reward = 0
    steps = 0

    terminated = False
    truncated = False

    while not (terminated or truncated):
        action = env.action_space.sample()

        state, reward, terminated, truncated, info = env.step(action)

        total_reward += reward
        steps += 1

    average_reward = total_reward / steps

    print("Environment:", env_name)
    print("Total Reward:", total_reward)
    print("Average Reward:", average_reward)
    print("Total Steps:", steps)
    print()

    env.close()


random_agent("CartPole-v1")
random_agent("MountainCar-v0")
random_agent("FrozenLake-v1")
# Out:
# Environment: CartPole-v1
# Total Reward: 40.0
# Average Reward: 1.0
# Total Steps: 40
#
# Environment: MountainCar-v0
# Total Reward: -200.0
# Average Reward: -1.0
# Total Steps: 200
#
# Environment: FrozenLake-v1
# Total Reward: 0
# Average Reward: 0.0
# Total Steps: 9
